# %% [markdown]
# <a href="https://colab.research.google.com/github/Ragul-S-2025/ML/blob/main/knnregressor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import needed Libraies and datasets

import pandas as pd
data=pd.read_csv("/content/Car_Price_Prediction.csv")
data
# Out:
#        Make    Model  Year  Engine Size  Mileage Fuel Type Transmission  \
# 0     Honda  Model B  2015          3.9    74176    Petrol       Manual
# 1      Ford  Model C  2014          1.7    94799  Electric    Automatic
# 2       BMW  Model B  2006          4.1    98385  Electric       Manual
# 3     Honda  Model B  2015          2.6    88919  Electric    Automatic
# 4     Honda  Model C  2004          3.4   138482    Petrol    Automatic
# ..      ...      ...   ...          ...      ...       ...          ...
# 995  Toyota  Model D  2002          1.9     5445    Petrol       Manual
# 996   Honda  Model B  2020          3.1   149112    Diesel       Manual
# 997    Ford  Model C  2008          1.9   195387    Petrol    Automatic
# 998  Toyota  Model A  2003          4.4      246    Petrol    Automatic
# 999    Audi  Model C  2020          2.1    31153    Diesel    Automatic
#
#             Price
# 0    30246.207931
# 1    22785.747684
# 2    25760.290347
# 3    25638.003491
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Make          1000 non-null   object
#  1   Model         1000 non-null   object
#  2   Year          1000 non-null   int64
#  3   Engine Size   1000 non-null   float64
#  4   Mileage       1000 non-null   int64
#  5   Fuel Type     1000 non-null   object
#  6   Transmission  1000 non-null   object
#  7   Price         1000 non-null   float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 62.6+ KB

# %%
# checkingg null values
data.isnull().sum()
# Out:
# Make            0
# Model           0
# Year            0
# Engine Size     0
# Mileage         0
# Fuel Type       0
# Transmission    0
# Price           0
# dtype: int64

# %%
# One hot encoding for change categical into numerical

data=pd.get_dummies(data,drop_first=True,dtype=int)
data
# Out:
#      Year  Engine Size  Mileage         Price  Make_BMW  Make_Ford  \
# 0    2015          3.9    74176  30246.207931         0          0
# 1    2014          1.7    94799  22785.747684         0          1
# 2    2006          4.1    98385  25760.290347         1          0
# 3    2015          2.6    88919  25638.003491         0          0
# 4    2004          3.4   138482  21021.386657         0          0
# ..    ...          ...      ...           ...       ...        ...
# 995  2002          1.9     5445  22765.597091         0          0
# 996  2020          3.1   149112  30392.575567         0          0
# 997  2008          1.9   195387  16446.892292         0          1
# 998  2003          4.4      246  27396.156708         0          0
# 999  2020          2.1    31153  31620.864907         0          0
#
#      Make_Honda  Make_Toyota  Model_Model B  Model_Model C  Model_Model D  \
# 0             1            0              1              0              0
# ...

# %%
x=data[["Year","Fuel Type_Electric","Transmission_Manual"]]
x
# Out:
#      Year  Fuel Type_Electric  Transmission_Manual
# 0    2015                   0                    1
# 1    2014                   1                    0
# 2    2006                   1                    1
# 3    2015                   1                    0
# 4    2004                   0                    0
# ..    ...                 ...                  ...
# 995  2002                   0                    1
# 996  2020                   0                    1
# 997  2008                   0                    0
# 998  2003                   0                    0
# 999  2020                   0                    0
#
# [1000 rows x 3 columns]

# %%
y=data[["Price"]]
y
# Out:
#             Price
# 0    30246.207931
# 1    22785.747684
# 2    25760.290347
# 3    25638.003491
# 4    21021.386657
# ..            ...
# 995  22765.597091
# 996  30392.575567
# 997  16446.892292
# 998  27396.156708
# 999  31620.864907
#
# [1000 rows x 1 columns]

# %%
# Test and Train test split

import numpy as np
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=0)

# %%
# using standard scalar for improving accuracy
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
data=sc.fit_transform(data)
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
# model training
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors=5)
knn.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred=knn.predict(x_test)
y_pred
# Out:
# array([[30744.80867442],
#        [27844.51882293],
#        [21894.98244345],
#        [23932.1607936 ],
#        [25397.80172195],
#        [25738.55352091],
#        [25125.13496884],
#        [22681.58887346],
#        [30000.44889534],
#        [26649.43459806],
#        [20794.06758961],
#        [25067.64277116],
#        [21535.66580444],
#        [26649.779704  ],
#        [22054.50500783],
#        [20045.97013805],
#        [31250.92615119],
#        [21689.0305527 ],
#        [30727.11305607],
#        [22417.85025374],
#        [17323.66214085],
#        [19718.8180632 ],
#        [23847.21361118],
#        [28611.63512426],
#        [29074.23014831],
#        [25776.17704112],
#        [22337.40532325],
#        [20045.97013805],
#        [25866.30737346],
#        [27508.98025396],
#        [22337.40532325],
#        [24069.38443423],
#        [24069.38443423],
#        [27220.83314473],
#        [25668.15511793],
#        [26649.779704  ],
#        [27220.83314473],
# ...

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error


mse = mean_squared_error(y_test, y_pred)
mse
r2=r2_score(y_test, y_pred)
r2
# Out:
# 0.24834563374885

# %%
mse
# Out:
# 19523585.12993904

# %%
import pickle

# %%
file_name="price.sav"

# %%
pickle.dump(knn,open("price","wb"))

# %%
out=pickle.load(open("price","rb"))

# %%
out=knn.predict([[2013,0,1]])
out
# Out:
# array([[32451.03795892]])
