# %% [markdown]
# <a href="https://colab.research.google.com/github/Ragul-S-2025/ML/blob/main/GridCV_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the Libraies
import numpy as np
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('/content/insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes
# 0   19  27.900         0  16884.92400         0           1
# 1   18  33.770         1   1725.55230         1           0
# 2   28  33.000         3   4449.46200         1           0
# 3   33  22.705         0  21984.47061         1           0
# 4   32  28.880         0   3866.85520         1           0

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor

param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'max_features': ['sqrt', 'log2']
}

grid = GridSearchCV(GradientBoostingRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1)
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# GridSearchCV(estimator=GradientBoostingRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [100, 200]},
#              verbose=3)

# %%
from sklearn.model_selection import GridSearchCV

# Assuming 'grid' is your GridSearchCV object and has been fitted to the data
print("Best parameters:", grid.best_params_)

# Access the mean test score for the best parameters
best_index = grid.best_index_
best_r2_score = grid.cv_results_['mean_test_score'][best_index]
# Printing the best R² score
print("r2:",best_r2_score)
# Out:
# Best parameters: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# r2: 0.7730800727526423

# %%
table=pd.DataFrame.from_dict(grid.cv_results_)
table.sort_values('rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 2        0.988744      0.058611         0.020586        0.007546
# 33       1.051276      0.266519         0.019571        0.003201
# 19       0.464887      0.009929         0.005925        0.000054
# 1        1.725116      0.326753         0.027708        0.010637
# 26       0.234658      0.006070         0.003904        0.000050
# 42       0.290172      0.015051         0.004917        0.000068
# 0        0.717994      0.084462         0.011394        0.003486
# 8        0.350997      0.016965         0.006734        0.000707
# 11       0.679883      0.098429         0.008760        0.000737
# 25       0.515557      0.017746         0.007004        0.000050
# 43       0.876012      0.215389         0.010951        0.002746
# 9        0.960232      0.223473         0.020259        0.006420
# 32       0.352768      0.007618         0.006486        0.000147
# 41       0.683167      0.017418         0.011508        0.001513
# 20       0.270645      0.054141         0.005576        0.002463
# 17       0.516928      0.013931         0.007561        0.001076
# 30       0.232662      0.014902         0.003861        0.000088
# 6        0.291724      0.009493         0.004760        0.000152
# 21       0.820567      0.131091         0.011897        0.003352
# 24       0.263037      0.008219         0.004543        0.000085
# 28       0.236746      0.009218         0.003979        0.000164
# 38       0.284622      0.015329         0.004722        0.000126
# 22       0.354708      0.051128         0.005269        0.001526
# 10       0.499849      0.064842         0.008381        0.004845
# 16       0.263603      0.011530         0.004824        0.000816
# 7        0.588543      0.017764         0.008039        0.000357
# 40       0.353437      0.020569         0.006376        0.000226
# 27       0.462468      0.010817         0.005819        0.000051
# 5        0.607798      0.014796         0.008207        0.000097
# 15       0.582200      0.016128         0.008183        0.000465
# 34       0.464578      0.055511         0.007684        0.003245
# 3        1.566131      0.436851         0.013534        0.004708
# 13       0.616906      0.021304         0.008376        0.000059
# 47       0.560906      0.034467         0.007459        0.000632
# 36       0.302005      0.019784         0.004974        0.000201
# 4        0.308029      0.020528         0.005038        0.000149
# 46       0.280200      0.008104         0.005805        0.001807
# 29       0.477594      0.031938         0.005914        0.000116
# 37       0.604491      0.025127         0.008174        0.000338
# 35       0.618696      0.046171         0.008103        0.000251
# 12       0.296203      0.015289         0.004995        0.000230
# 44       0.495043      0.066161         0.006777        0.003513
# 45       0.683939      0.115964         0.008138        0.000083
# 23       0.481979      0.044894         0.005830        0.000113
# 14       0.287221      0.011647         0.004760        0.000056
# 31       0.455481      0.017071         0.005731        0.000056
# 18       0.234340      0.008779         0.003944        0.000108
# 39       0.573517      0.015165         0.007600        0.000093
#
#    param_max_depth param_max_features  param_min_samples_leaf  \
# 2             None               sqrt                       1
# 33              20               sqrt                       1
# 19              10               sqrt                       1
# 1             None               sqrt                       1
# 26              10               log2                       1
# 42              20               log2                       1
# 0             None               sqrt                       1
# 8             None               log2                       1
# 11            None               log2                       1
# 25              10               log2                       1
# 43              20               log2                       1
# 9             None               log2                       1
# 32              20               sqrt                       1
# 41              20               log2                       1
# 20              10               sqrt                       2
# 17              10               sqrt                       1
# 30              10               log2                       2
# 6             None               sqrt                       2
# 21              10               sqrt                       2
# 24              10               log2                       1
# 28              10               log2                       2
# 38              20               sqrt                       2
# 22              10               sqrt                       2
# 10            None               log2                       1
# 16              10               sqrt                       1
# 7             None               sqrt                       2
# 40              20               log2                       1
# 27              10               log2                       1
# 5             None               sqrt                       2
# 15            None               log2                       2
# 34              20               sqrt                       1
# 3             None               sqrt                       1
# 13            None               log2                       2
# 47              20               log2                       2
# 36              20               sqrt                       2
# 4             None               sqrt                       2
# 46              20               log2                       2
# 29              10               log2                       2
# 37              20               sqrt                       2
# 35              20               sqrt                       1
# 12            None               log2                       2
# 44              20               log2                       2
# 45              20               log2                       2
# 23              10               sqrt                       2
# 14            None               log2                       2
# 31              10               log2                       2
# 18              10               sqrt                       1
# 39              20               sqrt                       2
#
#     param_min_samples_split  param_n_estimators  \
# 2                         5                 100
# 33                        2                 200
# 19                        5                 200
# 1                         2                 200
# 26                        5                 100
# 42                        5                 100
# 0                         2                 100
# 8                         2                 100
# 11                        5                 200
# 25                        2                 200
# 43                        5                 200
# 9                         2                 200
# 32                        2                 100
# 41                        2                 200
# 20                        2                 100
# 17                        2                 200
# 30                        5                 100
# 6                         5                 100
# 21                        2                 200
# 24                        2                 100
# 28                        2                 100
# 38                        5                 100
# 22                        5                 100
# 10                        5                 100
# 16                        2                 100
# 7                         5                 200
# 40                        2                 100
# 27                        5                 200
# 5                         2                 200
# 15                        5                 200
# 34                        5                 100
# 3                         5                 200
# 13                        2                 200
# 47                        5                 200
# 36                        2                 100
# 4                         2                 100
# 46                        5                 100
# 29                        2                 200
# 37                        2                 200
# 35                        5                 200
# 12                        2                 100
# 44                        2                 100
# 45                        2                 200
# 23                        5                 200
# 14                        5                 100
# 31                        5                 200
# 18                        5                 100
# 39                        5                 200
#
#                                                params  split0_test_score  \
# 2   {'max_depth': None, 'max_features': 'sqrt', 'm...           0.789491
# 33  {'max_depth': 20, 'max_features': 'sqrt', 'min...           0.772087
# 19  {'max_depth': 10, 'max_features': 'sqrt', 'min...           0.798617
# 1   {'max_depth': None, 'max_features': 'sqrt', 'm...           0.775845
# 26  {'max_depth': 10, 'max_features': 'log2', 'min...           0.788791
# 42  {'max_depth': 20, 'max_features': 'log2', 'min...           0.780764
# 0   {'max_depth': None, 'max_features': 'sqrt', 'm...           0.781036
# 8   {'max_depth': None, 'max_features': 'log2', 'm...           0.777735
# 11  {'max_depth': None, 'max_features': 'log2', 'm...           0.793279
# 25  {'max_depth': 10, 'max_features': 'log2', 'min...           0.767836
# 43  {'max_depth': 20, 'max_features': 'log2', 'min...           0.782663
# 9   {'max_depth': None, 'max_features': 'log2', 'm...           0.769586
# 32  {'max_depth': 20, 'max_features': 'sqrt', 'min...           0.781448
# 41  {'max_depth': 20, 'max_features': 'log2', 'min...           0.774208
# 20  {'max_depth': 10, 'max_features': 'sqrt', 'min...           0.781326
# 17  {'max_depth': 10, 'max_features': 'sqrt', 'min...           0.782782
# 30  {'max_depth': 10, 'max_features': 'log2', 'min...           0.779972
# 6   {'max_depth': None, 'max_features': 'sqrt', 'm...           0.780592
# 21  {'max_depth': 10, 'max_features': 'sqrt', 'min...           0.785859
# 24  {'max_depth': 10, 'max_features': 'log2', 'min...           0.779171
# 28  {'max_depth': 10, 'max_features': 'log2', 'min...           0.786398
# 38  {'max_depth': 20, 'max_features': 'sqrt', 'min...           0.781014
# 22  {'max_depth': 10, 'max_features': 'sqrt', 'min...           0.778964
# 10  {'max_depth': None, 'max_features': 'log2', 'm...           0.772231
# 16  {'max_depth': 10, 'max_features': 'sqrt', 'min...           0.766585
# 7   {'max_depth': None, 'max_features': 'sqrt', 'm...           0.777935
# 40  {'max_depth': 20, 'max_features': 'log2', 'min...           0.771656
# 27  {'max_depth': 10, 'max_features': 'log2', 'min...           0.775002
# 5   {'max_depth': None, 'max_features': 'sqrt', 'm...           0.782888
# 15  {'max_depth': None, 'max_features': 'log2', 'm...           0.772486
# 34  {'max_depth': 20, 'max_features': 'sqrt', 'min...           0.773729
# 3   {'max_depth': None, 'max_features': 'sqrt', 'm...           0.774740
# 13  {'max_depth': None, 'max_features': 'log2', 'm...           0.775910
# 47  {'max_depth': 20, 'max_features': 'log2', 'min...           0.768325
# 36  {'max_depth': 20, 'max_features': 'sqrt', 'min...           0.776458
# 4   {'max_depth': None, 'max_features': 'sqrt', 'm...           0.775065
# 46  {'max_depth': 20, 'max_features': 'log2', 'min...           0.778552
# 29  {'max_depth': 10, 'max_features': 'log2', 'min...           0.779537
# 37  {'max_depth': 20, 'max_features': 'sqrt', 'min...           0.772290
# 35  {'max_depth': 20, 'max_features': 'sqrt', 'min...           0.755189
# 12  {'max_depth': None, 'max_features': 'log2', 'm...           0.770257
# 44  {'max_depth': 20, 'max_features': 'log2', 'min...           0.758567
# 45  {'max_depth': 20, 'max_features': 'log2', 'min...           0.771034
# 23  {'max_depth': 10, 'max_features': 'sqrt', 'min...           0.771797
# 14  {'max_depth': None, 'max_features': 'log2', 'm...           0.765452
# 31  {'max_depth': 10, 'max_features': 'log2', 'min...           0.767478
# 18  {'max_depth': 10, 'max_features': 'sqrt', 'min...           0.766789
# 39  {'max_depth': 20, 'max_features': 'sqrt', 'min...           0.767010
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 2            0.737779           0.806321           0.793607
# 33           0.740815           0.795191           0.822708
# 19           0.726884           0.801456           0.796484
# 1            0.730314           0.801336           0.811933
# 26           0.730670           0.803839           0.791439
# 42           0.742336           0.792880           0.801735
# 0            0.722766           0.805050           0.801457
# 8            0.742828           0.802965           0.785866
# 11           0.742212           0.792986           0.783344
# 25           0.717658           0.809170           0.801001
# 43           0.729722           0.800006           0.785788
# 9            0.711146           0.816815           0.794725
# 32           0.737585           0.802229           0.789036
# 41           0.738310           0.791084           0.796482
# 20           0.723150           0.800297           0.800412
